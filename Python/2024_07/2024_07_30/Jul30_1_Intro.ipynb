# %% [markdown]
# #Colab
# 구글에서 제공하는 클라우드 기반 파이썬 코드 실행 환경
# 클라우드 기반으로 한 주피터 노트북 개발 환경
# GPU 성능이 필요한 작업을 하는 경우 Colab이 유용함
# Numpy, Pandas, keras, sciktit-learn, tensorflow ... 같은 패키지들이 기본 탑재되어 있음
# ---명령어들---
# -Ctrl + Enter : 해당 셀 실행
# -Shift + Enter : 해당 셀을 실행하고 다음 셀로 이동
# -Ctrl + M + Z : 실행했던 내용을 취소
# -Ctrl + M + D : 커서가 위치한 셀을 지우기
# -Ctrl + ;       : 텍스트 셀 생성

# %%
print("test")
# Out:
# test
